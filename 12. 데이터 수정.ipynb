# %% [markdown]
# # 12. 데이터 수정

# %%
import pandas as pd
df= pd.read_excel('score.xlsx', index_col='지원번호')
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %% [markdown]
# ## Column 수정

# %%
df['학교'].replace({'북산고' : '상북고'})
# Out:
# 지원번호
# 1번    상북고
# 2번    상북고
# 3번    상북고
# 4번    상북고
# 5번    상북고
# 6번    능남고
# 7번    능남고
# 8번    능남고
# Name: 학교, dtype: object

# %%
df['학교'].replace({'북산고' : '상북고', '능남고' :'무슨고'})
# Out:
# 지원번호
# 1번    상북고
# 2번    상북고
# 3번    상북고
# 4번    상북고
# 5번    상북고
# 6번    무슨고
# 7번    무슨고
# 8번    무슨고
# Name: 학교, dtype: object

# %%
df['학교'].replace({'북산고' : '상북고'}, inplace=True)

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  상북고  197   90   85  100  95  85      Python
# 2번    정대만  상북고  184   40   35   50  55  25        Java
# 3번    송태섭  상북고  168   80   75   70  80  75  Javascript
# 4번    서태웅  상북고  187   40   60   70  75  80         NaN
# 5번    강백호  상북고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df['SW특기'].str.lower()
# Out:
# 지원번호
# 1번        python
# 2번          java
# 3번    javascript
# 4번           NaN
# 5번           NaN
# 6번             c
# 7번        python
# 8번            c#
# Name: SW특기, dtype: object

# %%
df['SW특기'] = df['SW특기'].str.lower()
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  상북고  197   90   85  100  95  85      python
# 2번    정대만  상북고  184   40   35   50  55  25        java
# 3번    송태섭  상북고  168   80   75   70  80  75  javascript
# 4번    서태웅  상북고  187   40   60   70  75  80         NaN
# 5번    강백호  상북고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           c
# 7번    황태산  능남고  188   55   65   45  40  35      python
# 8번    윤대협  능남고  190  100   85   90  95  95          c#

# %%
df['SW특기']= df['SW특기'].str.upper()
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  상북고  197   90   85  100  95  85      PYTHON
# 2번    정대만  상북고  184   40   35   50  55  25        JAVA
# 3번    송태섭  상북고  168   80   75   70  80  75  JAVASCRIPT
# 4번    서태웅  상북고  187   40   60   70  75  80         NaN
# 5번    강백호  상북고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df['학교'] = df['학교'] + '등학교' 
df
# Out:
#        이름         학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  상북고등학교등학교  197   90   85  100  95  85      PYTHON
# 2번    정대만  상북고등학교등학교  184   40   35   50  55  25        JAVA
# 3번    송태섭  상북고등학교등학교  168   80   75   70  80  75  JAVASCRIPT
# 4번    서태웅  상북고등학교등학교  187   40   60   70  75  80         NaN
# 5번    강백호  상북고등학교등학교  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고등학교등학교  202   80  100   95  85  80           C
# 7번    황태산  능남고등학교등학교  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고등학교등학교  190  100   85   90  95  95          C#

# %% [markdown]
# ## Column 추가

# %%
df['총합'] = df['국어'] + df['영어'] + df['수학'] + df['과학'] + df['사회']
df
# Out:
#        이름         학교    키   국어   영어   수학  과학  사회        SW특기   총함   총합
# 지원번호
# 1번    채치수  상북고등학교등학교  197   90   85  100  95  85      PYTHON  455  455
# 2번    정대만  상북고등학교등학교  184   40   35   50  55  25        JAVA  205  205
# 3번    송태섭  상북고등학교등학교  168   80   75   70  80  75  JAVASCRIPT  380  380
# 4번    서태웅  상북고등학교등학교  187   40   60   70  75  80         NaN  325  325
# 5번    강백호  상북고등학교등학교  188   15   20   10  35  10         NaN   90   90
# 6번    변덕규  능남고등학교등학교  202   80  100   95  85  80           C  440  440
# 7번    황태산  능남고등학교등학교  188   55   65   45  40  35      PYTHON  240  240
# 8번    윤대협  능남고등학교등학교  190  100   85   90  95  95          C#  465  465

# %%
df['결과'] = 'Fail'
df
# Out:
#        이름         학교    키   국어   영어   수학  과학  사회        SW특기   총함   총합    결과
# 지원번호
# 1번    채치수  상북고등학교등학교  197   90   85  100  95  85      PYTHON  455  455  Fail
# 2번    정대만  상북고등학교등학교  184   40   35   50  55  25        JAVA  205  205  Fail
# 3번    송태섭  상북고등학교등학교  168   80   75   70  80  75  JAVASCRIPT  380  380  Fail
# 4번    서태웅  상북고등학교등학교  187   40   60   70  75  80         NaN  325  325  Fail
# 5번    강백호  상북고등학교등학교  188   15   20   10  35  10         NaN   90   90  Fail
# 6번    변덕규  능남고등학교등학교  202   80  100   95  85  80           C  440  440  Fail
# 7번    황태산  능남고등학교등학교  188   55   65   45  40  35      PYTHON  240  240  Fail
# 8번    윤대협  능남고등학교등학교  190  100   85   90  95  95          C#  465  465  Fail

# %%
df.loc[df['총합']> 400, '결과'] = 'Pass' # 총합이 400보다 큰 데이터 Pass로 업데이트
df
# Out:
#        이름         학교    키   국어   영어   수학  과학  사회        SW특기   총함   총합    결과
# 지원번호
# 1번    채치수  상북고등학교등학교  197   90   85  100  95  85      PYTHON  455  455  Pass
# 2번    정대만  상북고등학교등학교  184   40   35   50  55  25        JAVA  205  205  Fail
# 3번    송태섭  상북고등학교등학교  168   80   75   70  80  75  JAVASCRIPT  380  380  Fail
# 4번    서태웅  상북고등학교등학교  187   40   60   70  75  80         NaN  325  325  Fail
# 5번    강백호  상북고등학교등학교  188   15   20   10  35  10         NaN   90   90  Fail
# 6번    변덕규  능남고등학교등학교  202   80  100   95  85  80           C  440  440  Pass
# 7번    황태산  능남고등학교등학교  188   55   65   45  40  35      PYTHON  240  240  Fail
# 8번    윤대협  능남고등학교등학교  190  100   85   90  95  95          C#  465  465  Pass

# %% [markdown]
# ## Column 삭제

# %%
df.drop(columns=['총합'], inplace= True)
df
# Out:
#        이름         학교    키   국어   영어   수학  과학  사회        SW특기    결과
# 지원번호
# 1번    채치수  상북고등학교등학교  197   90   85  100  95  85      PYTHON  Pass
# 2번    정대만  상북고등학교등학교  184   40   35   50  55  25        JAVA  Fail
# 3번    송태섭  상북고등학교등학교  168   80   75   70  80  75  JAVASCRIPT  Fail
# 4번    서태웅  상북고등학교등학교  187   40   60   70  75  80         NaN  Fail
# 5번    강백호  상북고등학교등학교  188   15   20   10  35  10         NaN  Fail
# 6번    변덕규  능남고등학교등학교  202   80  100   95  85  80           C  Pass
# 7번    황태산  능남고등학교등학교  188   55   65   45  40  35      PYTHON  Fail
# 8번    윤대협  능남고등학교등학교  190  100   85   90  95  95          C#  Pass

# %%
df.drop(columns=['국어', '영어', '수학'])
# Out:
#        이름         학교    키  과학  사회        SW특기    결과
# 지원번호
# 1번    채치수  상북고등학교등학교  197  95  85      PYTHON  Pass
# 2번    정대만  상북고등학교등학교  184  55  25        JAVA  Fail
# 3번    송태섭  상북고등학교등학교  168  80  75  JAVASCRIPT  Fail
# 4번    서태웅  상북고등학교등학교  187  75  80         NaN  Fail
# 5번    강백호  상북고등학교등학교  188  35  10         NaN  Fail
# 6번    변덕규  능남고등학교등학교  202  85  80           C  Pass
# 7번    황태산  능남고등학교등학교  188  40  35      PYTHON  Fail
# 8번    윤대협  능남고등학교등학교  190  95  95          C#  Pass

# %%
 df.drop(index='4번') # 4번 학생 데이터 row를 삭제
# Out:
#        이름         학교    키   국어   영어   수학  과학  사회        SW특기    결과
# 지원번호
# 1번    채치수  상북고등학교등학교  197   90   85  100  95  85      PYTHON  Pass
# 2번    정대만  상북고등학교등학교  184   40   35   50  55  25        JAVA  Fail
# 3번    송태섭  상북고등학교등학교  168   80   75   70  80  75  JAVASCRIPT  Fail
# 5번    강백호  상북고등학교등학교  188   15   20   10  35  10         NaN  Fail
# 6번    변덕규  능남고등학교등학교  202   80  100   95  85  80           C  Pass
# 7번    황태산  능남고등학교등학교  188   55   65   45  40  35      PYTHON  Fail
# 8번    윤대협  능남고등학교등학교  190  100   85   90  95  95          C#  Pass

# %%
filt = df['수학'] < 80
df[filt]
# Out:
#        이름         학교    키  국어  영어  수학  과학  사회        SW특기    결과
# 지원번호
# 2번    정대만  상북고등학교등학교  184  40  35  50  55  25        JAVA  Fail
# 3번    송태섭  상북고등학교등학교  168  80  75  70  80  75  JAVASCRIPT  Fail
# 4번    서태웅  상북고등학교등학교  187  40  60  70  75  80         NaN  Fail
# 5번    강백호  상북고등학교등학교  188  15  20  10  35  10         NaN  Fail
# 7번    황태산  능남고등학교등학교  188  55  65  45  40  35      PYTHON  Fail

# %%
df[filt].index
# Out:
# Index(['2번', '3번', '4번', '5번', '7번'], dtype='object', name='지원번호')

# %%
df.drop(index=df[filt].index)
# Out:
#        이름         학교    키   국어   영어   수학  과학  사회    SW특기    결과
# 지원번호
# 1번    채치수  상북고등학교등학교  197   90   85  100  95  85  PYTHON  Pass
# 6번    변덕규  능남고등학교등학교  202   80  100   95  85  80       C  Pass
# 8번    윤대협  능남고등학교등학교  190  100   85   90  95  95      C#  Pass

# %% [markdown]
# ## Row 추가

# %%
df['총합'] = df['영어'] + df['국어'] + df['수학'] + df['과학'] + df['사회']
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기   총합
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python  455
# 2번    정대만  북산고  184   40   35   50  55  25        Java  205
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript  380
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN  325
# 5번    강백호  북산고  188   15   20   10  35  10         NaN   90
# 6번    변덕규  능남고  202   80  100   95  85  80           C  440
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON  240
# 8번    윤대협  능남고  190  100   85   90  95  95          C#  465

# %%
df.loc['9번'] = ['이정환', '해남고등학교', 184, 90, 90, 90, 90, 90, 'Kotlin', 'Pass', 450]
df
# Out:
#        이름         학교    키   국어   영어   수학  과학  사회        SW특기    결과   총합
# 지원번호
# 1번    채치수  상북고등학교등학교  197   90   85  100  95  85      PYTHON  Pass  455
# 2번    정대만  상북고등학교등학교  184   40   35   50  55  25        JAVA  Fail  205
# 3번    송태섭  상북고등학교등학교  168   80   75   70  80  75  JAVASCRIPT  Fail  380
# 4번    서태웅  상북고등학교등학교  187   40   60   70  75  80         NaN  Fail  325
# 5번    강백호  상북고등학교등학교  188   15   20   10  35  10         NaN  Fail   90
# 6번    변덕규  능남고등학교등학교  202   80  100   95  85  80           C  Pass  440
# 7번    황태산  능남고등학교등학교  188   55   65   45  40  35      PYTHON  Fail  240
# 8번    윤대협  능남고등학교등학교  190  100   85   90  95  95          C#  Pass  465
# 9번    이정환     해남고등학교  184   90   90   90  90  90      Kotlin  Pass  450

# %% [markdown]
# ## Cell 수정

# %%
df.loc['4번', 'SW특기'] = 'Python'
df
# Out:
#        이름         학교    키   국어   영어   수학  과학  사회        SW특기    결과   총합
# 지원번호
# 1번    채치수  상북고등학교등학교  197   90   85  100  95  85      PYTHON  Pass  455
# 2번    정대만  상북고등학교등학교  184   40   35   50  55  25        JAVA  Fail  205
# 3번    송태섭  상북고등학교등학교  168   80   75   70  80  75  JAVASCRIPT  Fail  380
# 4번    서태웅  상북고등학교등학교  187   40   60   70  75  80      Python  Fail  325
# 5번    강백호  상북고등학교등학교  188   15   20   10  35  10         NaN  Fail   90
# 6번    변덕규  능남고등학교등학교  202   80  100   95  85  80           C  Pass  440
# 7번    황태산  능남고등학교등학교  188   55   65   45  40  35      PYTHON  Fail  240
# 8번    윤대협  능남고등학교등학교  190  100   85   90  95  95          C#  Pass  465
# 9번    이정환     해남고등학교  184   90   90   90  90  90      Kotlin  Pass  450

# %%
df.loc['5번', ['학교', 'SW특기']] = ['능남고등학교', 'C']
df
# Out:
#        이름         학교    키   국어   영어   수학  과학  사회        SW특기    결과   총합
# 지원번호
# 1번    채치수  상북고등학교등학교  197   90   85  100  95  85      PYTHON  Pass  455
# 2번    정대만  상북고등학교등학교  184   40   35   50  55  25        JAVA  Fail  205
# 3번    송태섭  상북고등학교등학교  168   80   75   70  80  75  JAVASCRIPT  Fail  380
# 4번    서태웅  상북고등학교등학교  187   40   60   70  75  80      Python  Fail  325
# 5번    강백호     능남고등학교  188   15   20   10  35  10           C  Fail   90
# 6번    변덕규  능남고등학교등학교  202   80  100   95  85  80           C  Pass  440
# 7번    황태산  능남고등학교등학교  188   55   65   45  40  35      PYTHON  Fail  240
# 8번    윤대협  능남고등학교등학교  190  100   85   90  95  95          C#  Pass  465
# 9번    이정환     해남고등학교  184   90   90   90  90  90      Kotlin  Pass  450

# %% [markdown]
# ## Column 순서 변경

# %%
cols = list(df.columns)
cols
# Out:
# ['총합', '이름', '학교', '키', '국어', '영어', '수학', '과학', '사회', 'SW특기', '결과']

# %%
df = df[[cols[-1]] + cols[0:-1]] # 맨 뒤에 있는 결과 Column을 앞으로 가져오고, 나머지 Column 들과 합쳐서 순서 변경
df
# Out:
#        총합   이름      학교    키   국어   영어   수학  과학  사회        SW특기    결과
# 지원번호
# 1번    455  채치수     북산고  197   90   85  100  95  85      Python  Fail
# 2번    205  정대만     북산고  184   40   35   50  55  25        Java  Fail
# 3번    380  송태섭     북산고  168   80   75   70  80  75  Javascript  Fail
# 4번    325  서태웅     북산고  187   40   60   70  75  80         NaN  Fail
# 5번     90  강백호     북산고  188   15   20   10  35  10         NaN  Fail
# 6번    440  변덕규     능남고  202   80  100   95  85  80           C  Fail
# 7번    240  황태산     능남고  188   55   65   45  40  35      PYTHON  Fail
# 8번    465  윤대협     능남고  190  100   85   90  95  95          C#  Fail
# 9번    450  이정환  해남고등학교  184   90   90   90  90  90      Kotlin  Pass

# %%
cols
# Out:
# ['이름', '학교', '키', '국어', '영어', '수학', '과학', '사회', 'SW특기', '결과', '총합']

# %%
import pandas as pd
df= pd.read_excel('score.xlsx', index_col='지원번호')
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df['총합'] = df['국어'] + df['영어'] + df['수학'] + df['과학'] + df['사회']
df['결과'] = 'Fail'
df.loc['9번'] = ['이정환', '해남고등학교', 184, 90, 90, 90, 90, 90, 'Kotlin', 450, 'Pass']
df
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회        SW특기   총합    결과
# 지원번호
# 1번    채치수     북산고  197   90   85  100  95  85      Python  455  Fail
# 2번    정대만     북산고  184   40   35   50  55  25        Java  205  Fail
# 3번    송태섭     북산고  168   80   75   70  80  75  Javascript  380  Fail
# 4번    서태웅     북산고  187   40   60   70  75  80         NaN  325  Fail
# 5번    강백호     북산고  188   15   20   10  35  10         NaN   90  Fail
# 6번    변덕규     능남고  202   80  100   95  85  80           C  440  Fail
# 7번    황태산     능남고  188   55   65   45  40  35      PYTHON  240  Fail
# 8번    윤대협     능남고  190  100   85   90  95  95          C#  465  Fail
# 9번    이정환  해남고등학교  184   90   90   90  90  90      Kotlin  450  Pass

# %%
df = df[[cols[-1]] + cols[0:-1]] # 맨 뒤에 있는 결과 Column을 앞으로 가져오고, 나머지 Column 들과 합쳐서 순서 변경
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 df = df[[cols[-1]] + cols[0:-1]] # 맨 뒤에 있는 결과 Column을 앞으로 가져오고, 나머지 Column 들과 합쳐서 순서 변경
#       2 df
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
# ...

# %%
cols = list(df.columns)
cols
# Out:
# ['총합', '이름', '학교', '키', '국어', '영어', '수학', '과학', '사회', 'SW특기', '결과']

# %%
df = df[cols[1:-1] + [cols[0]]] # 맨 뒤에 있는 결과 Column을 앞으로 가져오고, 나머지 Column 들과 합쳐서 순서 변경
df
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회        SW특기   총합
# 지원번호
# 1번    채치수     북산고  197   90   85  100  95  85      Python  455
# 2번    정대만     북산고  184   40   35   50  55  25        Java  205
# 3번    송태섭     북산고  168   80   75   70  80  75  Javascript  380
# 4번    서태웅     북산고  187   40   60   70  75  80         NaN  325
# 5번    강백호     북산고  188   15   20   10  35  10         NaN   90
# 6번    변덕규     능남고  202   80  100   95  85  80           C  440
# 7번    황태산     능남고  188   55   65   45  40  35      PYTHON  240
# 8번    윤대협     능남고  190  100   85   90  95  95          C#  465
# 9번    이정환  해남고등학교  184   90   90   90  90  90      Kotlin  450

# %%
import pandas as pd
df= pd.read_excel('score.xlsx', index_col='지원번호')
df['총합'] = df['국어'] + df['영어'] + df['수학'] + df['과학'] + df['사회']
df['결과'] = 'Fail'
df.loc['9번'] = ['이정환', '해남고등학교', 184, 90, 90, 90, 90, 90, 'Kotlin', 450, 'Pass']
df = df[[cols[-1]] + cols[0:-1]] # 맨 뒤에 있는 결과 Column을 앞으로 가져오고, 나머지 Column 들과 합쳐서 순서 변경
df
# Out:
#         결과   총합   이름      학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    Fail  455  채치수     북산고  197   90   85  100  95  85      Python
# 2번    Fail  205  정대만     북산고  184   40   35   50  55  25        Java
# 3번    Fail  380  송태섭     북산고  168   80   75   70  80  75  Javascript
# 4번    Fail  325  서태웅     북산고  187   40   60   70  75  80         NaN
# 5번    Fail   90  강백호     북산고  188   15   20   10  35  10         NaN
# 6번    Fail  440  변덕규     능남고  202   80  100   95  85  80           C
# 7번    Fail  240  황태산     능남고  188   55   65   45  40  35      PYTHON
# 8번    Fail  465  윤대협     능남고  190  100   85   90  95  95          C#
# 9번    Pass  450  이정환  해남고등학교  184   90   90   90  90  90      Kotlin

# %%
df = df[cols[1:]+[cols[0]]]
df
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회        SW특기    결과   총합
# 지원번호
# 1번    채치수     북산고  197   90   85  100  95  85      Python  Fail  455
# 2번    정대만     북산고  184   40   35   50  55  25        Java  Fail  205
# 3번    송태섭     북산고  168   80   75   70  80  75  Javascript  Fail  380
# 4번    서태웅     북산고  187   40   60   70  75  80         NaN  Fail  325
# 5번    강백호     북산고  188   15   20   10  35  10         NaN  Fail   90
# 6번    변덕규     능남고  202   80  100   95  85  80           C  Fail  440
# 7번    황태산     능남고  188   55   65   45  40  35      PYTHON  Fail  240
# 8번    윤대협     능남고  190  100   85   90  95  95          C#  Fail  465
# 9번    이정환  해남고등학교  184   90   90   90  90  90      Kotlin  Pass  450

# %%
import pandas as pd
df= pd.read_excel('score.xlsx', index_col='지원번호')
df['총합'] = df['국어'] + df['영어'] + df['수학'] + df['과학'] + df['사회']
df['결과'] = 'Fail'
df.loc['9번'] = ['이정환', '해남고등학교', 184, 90, 90, 90, 90, 90, 'Kotlin', 450, 'Pass']
df
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회        SW특기   총합    결과
# 지원번호
# 1번    채치수     북산고  197   90   85  100  95  85      Python  455  Fail
# 2번    정대만     북산고  184   40   35   50  55  25        Java  205  Fail
# 3번    송태섭     북산고  168   80   75   70  80  75  Javascript  380  Fail
# 4번    서태웅     북산고  187   40   60   70  75  80         NaN  325  Fail
# 5번    강백호     북산고  188   15   20   10  35  10         NaN   90  Fail
# 6번    변덕규     능남고  202   80  100   95  85  80           C  440  Fail
# 7번    황태산     능남고  188   55   65   45  40  35      PYTHON  240  Fail
# 8번    윤대협     능남고  190  100   85   90  95  95          C#  465  Fail
# 9번    이정환  해남고등학교  184   90   90   90  90  90      Kotlin  450  Pass

# %%
cols3 = list[df.columns]

# %%
columns_list = [column for column in df.columns]

# %%
df= df[[columns_list[-1]]+columns_list[0:-1]]
df
# Out:
#         결과   이름      학교    키   국어   영어   수학  과학  사회        SW특기   총합
# 지원번호
# 1번    Fail  채치수     북산고  197   90   85  100  95  85      Python  455
# 2번    Fail  정대만     북산고  184   40   35   50  55  25        Java  205
# 3번    Fail  송태섭     북산고  168   80   75   70  80  75  Javascript  380
# 4번    Fail  서태웅     북산고  187   40   60   70  75  80         NaN  325
# 5번    Fail  강백호     북산고  188   15   20   10  35  10         NaN   90
# 6번    Fail  변덕규     능남고  202   80  100   95  85  80           C  440
# 7번    Fail  황태산     능남고  188   55   65   45  40  35      PYTHON  240
# 8번    Fail  윤대협     능남고  190  100   85   90  95  95          C#  465
# 9번    Pass  이정환  해남고등학교  184   90   90   90  90  90      Kotlin  450

# %%
columns_list2 = [column for column in df.columns]
columns_list2
# Out:
# ['결과', '이름', '학교', '키', '국어', '영어', '수학', '과학', '사회', 'SW특기', '총합']

# %%
df = df[columns_list2[1:]+[columns_list2[0]]]
df
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회        SW특기   총합    결과
# 지원번호
# 1번    채치수     북산고  197   90   85  100  95  85      Python  455  Fail
# 2번    정대만     북산고  184   40   35   50  55  25        Java  205  Fail
# 3번    송태섭     북산고  168   80   75   70  80  75  Javascript  380  Fail
# 4번    서태웅     북산고  187   40   60   70  75  80         NaN  325  Fail
# 5번    강백호     북산고  188   15   20   10  35  10         NaN   90  Fail
# 6번    변덕규     능남고  202   80  100   95  85  80           C  440  Fail
# 7번    황태산     능남고  188   55   65   45  40  35      PYTHON  240  Fail
# 8번    윤대협     능남고  190  100   85   90  95  95          C#  465  Fail
# 9번    이정환  해남고등학교  184   90   90   90  90  90      Kotlin  450  Pass

# %% [markdown]
# ## Column 이름 변경

# %%
df = df[['결과', '이름', '학교']]
df
# Out:
#         결과   이름      학교
# 지원번호
# 1번    Fail  채치수     북산고
# 2번    Fail  정대만     북산고
# 3번    Fail  송태섭     북산고
# 4번    Fail  서태웅     북산고
# 5번    Fail  강백호     북산고
# 6번    Fail  변덕규     능남고
# 7번    Fail  황태산     능남고
# 8번    Fail  윤대협     능남고
# 9번    Pass  이정환  해남고등학교

# %%
df.columns
# Out:
# Index(['결과', '이름', '학교'], dtype='object')

# %%
df.columns = ['Results', 'Name', 'School']
df
# Out:
#      Results Name  School
# 지원번호
# 1번      Fail  채치수     북산고
# 2번      Fail  정대만     북산고
# 3번      Fail  송태섭     북산고
# 4번      Fail  서태웅     북산고
# 5번      Fail  강백호     북산고
# 6번      Fail  변덕규     능남고
# 7번      Fail  황태산     능남고
# 8번      Fail  윤대협     능남고
# 9번      Pass  이정환  해남고등학교

# %%
df = df.rename(columns={df.columns[0]: '결과'}) #특정 인덱스 열 제목 바꾸기
df
# Out:
#         결과 Name  School
# 지원번호
# 1번    Fail  채치수     북산고
# 2번    Fail  정대만     북산고
# 3번    Fail  송태섭     북산고
# 4번    Fail  서태웅     북산고
# 5번    Fail  강백호     북산고
# 6번    Fail  변덕규     능남고
# 7번    Fail  황태산     능남고
# 8번    Fail  윤대협     능남고
# 9번    Pass  이정환  해남고등학교
